# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#### Linear Equation

# %%
x=np.arange(0,10,0.25)

# %%
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %%
y=x*4.23+36.07

# %%
plt.plot(x,y)

# %% [markdown]
# #### polynomial equation

# %%
y=x**2*4.23+36.07

# %%
y
# Out:
# array([ 36.07    ,  36.334375,  37.1275  ,  38.449375,  40.3     ,
#         42.679375,  45.5875  ,  49.024375,  52.99    ,  57.484375,
#         62.5075  ,  68.059375,  74.14    ,  80.749375,  87.8875  ,
#         95.554375, 103.75    , 112.474375, 121.7275  , 131.509375,
#        141.82    , 152.659375, 164.0275  , 175.924375, 188.35    ,
#        201.304375, 214.7875  , 228.799375, 243.34    , 258.409375,
#        274.0075  , 290.134375, 306.79    , 323.974375, 341.6875  ,
#        359.929375, 378.7     , 397.999375, 417.8275  , 438.184375])

# %%
plt.plot(x,y)

# %%
#### Logarithmic equation

# %%
plt.figure(figsize=(16,9))
plt.plot(x,np.log(x))
# Out:
# C:\Users\Bhargav\AppData\Local\Temp\ipykernel_25496\4224391832.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x,np.log(x))
